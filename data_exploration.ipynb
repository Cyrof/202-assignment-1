# %% [markdown]
# # Data Exploration
# Data exploration involves summarising the dataset's main characteristics and visualising its distribution and relationships. This step helps identify patterns, trends, and potential issues such as missing values, setting foundation for subsequent analysis and modelling.

# %% [markdown]
# ## Import Libraries
# Essential libraries such as `pandas`, `os`, and visualisation libraries like `matplotlib` are imported. These libraries provide the necessary functions to handle and visualise the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import os

# %% [markdown]
# ## Loading dataset
# The dataset is loaded from a CSV file from the `datasets` folder into a `pandas` `DataFrame`.

# %%
csv_path = f"{os.getcwd()}/datasets/obesityData.csv"

ob_df = pd.read_csv(csv_path) # ob_df --> obesity dataframe

# %% [markdown]
# ## Explore the Dataset
# Initial exploration involves checking the shape of the dataset, viewing the first few rows, and summarising basic statistics. This helps us understand the structure and basic characteristics of the data.

# %%
# view the first few rows
ob_df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
# Check the shape of the dataset
print(f"The dataset contains {ob_df.shape[0]} rows and {ob_df.shape[1]} columns.")
# Out:
# The dataset contains 2111 rows and 17 columns.

# %%
# Generate descriptive statistics for the data
ob_df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
# Check for missing values
ob_df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
# check data types
ob_df.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
# check duplicates 
ob_df[ob_df.duplicated()]
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 98   Female  21.0    1.52    42.0                             no   no   3.0
# 106  Female  25.0    1.57    55.0                             no  yes   2.0
# 174    Male  21.0    1.62    70.0                             no  yes   2.0
# 179    Male  21.0    1.62    70.0                             no  yes   2.0
# 184    Male  21.0    1.62    70.0                             no  yes   2.0
# 209  Female  22.0    1.69    65.0                            yes  yes   2.0
# 309  Female  16.0    1.66    58.0                             no   no   2.0
# 460  Female  18.0    1.62    55.0                            yes  yes   2.0
# 467    Male  22.0    1.74    75.0                            yes  yes   3.0
# 496    Male  18.0    1.72    53.0                            yes  yes   2.0
# 527  Female  21.0    1.52    42.0                             no  yes   3.0
# ...

# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# ### 1. **Visualise the distribution of ages**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(ob_df['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  ### 2. **Visualise the distribution of BMI (Body Mass Index)** <br>
# Assuming BMI is calculated as weight in kg divided by height in meters squared (BMI = Weight / (Height/100)**2)

# %%
ob_df['BMI'] = ob_df['Weight'] / (ob_df['Height'])**2

plt.figure(figsize=(10,6))
sns.histplot(ob_df['BMI'], bins=30, kde=True)
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 3. **Box plot of BMI by Gender**

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Gender', y='BMI', data=ob_df)
plt.title('BMI by Gender')
plt.xlabel('Gender')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# ### 4. **Correlation Heatmap**

# %%
# Convert categorical variables to numeric using Label Encoding
label_encoders = {}
for column in ob_df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    ob_df[column] = label_encoders[column].fit_transform(ob_df[column])
    
# Calculate the correlation matrix
correlation_matrix = ob_df.corr()

# Plot the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### 5. **Count plot of target variable** <br>
# `NObeyesdad` is the target variable for obesity levels

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='NObeyesdad', data=ob_df, palette='viridis')
plt.title('Count of Each Obesity Level')
plt.xlabel('Obesity Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_20587/3059877793.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='NObeyesdad', data=ob_df, palette='viridis')

# %% [markdown]
# ### 6. **Pariplot of a few selected features** <br>
# Chosen features are `age`, `height`, `weight`, and `BMI`

# %%
selected_features = ['Age', 'Height', 'Weight',  'BMI']
sns.pairplot(ob_df[selected_features])
plt.show()

# %% [markdown]
# ### 7. **Distribution of Family History with Overweight**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='family_history_with_overweight', data=ob_df, palette='viridis')
plt.title('Family History with OVerweight')
plt.xlabel('Family History')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_20587/885020468.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='family_history_with_overweight', data=ob_df, palette='viridis')

# %% [markdown]
# ### 8. **Count plot for a categorial feature (e.g, 'FAVC' - Frequent consumption of high caloric food)**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='FAVC', data=ob_df)
plt.title('Count Plot of Frequent Comsumption of High Caloric Food (FAVC)')
plt.xlabel('Frequent Consumption of High Caloric Food')
plt.ylabel('Count')
plt.show()
